# %%
import pandas as pd
import numpy as np

# %% [markdown]
# extraccion de datos

# %%
data=pd.read_csv("C:/Users/Leo/Desktop/daniela_curso/proyecto_1/naruto.csv", encoding='ANSI')
data.full()
# Out:
#      Unnamed: 0  Num_episode  \
# 0             1            1
# 1             2            2
# 2             3            3
# 3             4            4
# 4             5            5
# ..          ...          ...
# 495         496          496
# 496         497          497
# 497         498          498
# 498         499          499
# 499         500          500
#
#                                                  Title                Type  \
# 0                                           Homecoming  Mixed Canon/Filler
# 1                          The Akatsuki Makes Its Move  Mixed Canon/Filler
# 2                              The Results of Training  Mixed Canon/Filler
# 3                           The Jinchuriki of the Sand  Mixed Canon/Filler
# 4                             The Kazekage Stands Tall  Mixed Canon/Filler
# ..                                                 ...                 ...
# 495  Hidden Leaf Story, the Perfect Day for a Weddi...         Manga Canon
# ...

# %%
data.drop("Unnamed: 0", axis='columns',inplace=True)

# %%
#data.reset_index(drop=True)
#data.set_index('Num_episode',inplace=True)

# %%
data.head()
# Out:
#    Num_episode                        Title                Type  Year_launch  \
# 0            1                   Homecoming  Mixed Canon/Filler         2007
# 1            2  The Akatsuki Makes Its Move  Mixed Canon/Filler         2007
# 2            3      The Results of Training  Mixed Canon/Filler         2007
# 3            4   The Jinchuriki of the Sand  Mixed Canon/Filler         2007
# 4            5     The Kazekage Stands Tall  Mixed Canon/Filler         2007
#
#    Rate  Votes                Saga     Airdate
# 0   8.2    728  s1 Kazekage Rescue  2007-02-15
# 1   8.0    575  s1 Kazekage Rescue  2007-02-15
# 2   8.0    508  s1 Kazekage Rescue  2007-02-22
# 3   8.2    517  s1 Kazekage Rescue  2007-03-01
# 4   8.2    486  s1 Kazekage Rescue  2007-03-15

# %%
from datetime import datetime
import calendar
data['year'] = pd.to_datetime(data['Airdate']).dt.strftime('%Y')
data['month'] = pd.to_datetime(data['Airdate']).dt.strftime('%m')
data['day'] = pd.to_datetime(data['Airdate']).dt.strftime('%d')
data['month'] = data['month'].apply(lambda x: calendar.month_name[int(x)])

# %%
data['Rate'].value_counts()
# Out:
# Rate
# 8.4    31
# 8.2    29
# 8.5    25
# 8.3    24
# 7.7    22
# 8.0    20
# 6.7    18
# 6.6    17
# 6.4    17
# 7.5    17
# 8.1    16
# 7.9    16
# 7.8    14
# 7.2    13
# 7.3    12
# 7.4    12
# 6.2    12
# 5.8    12
# 6.1    12
# 8.6    11
# 7.1    10
# 6.5    10
# 6.8    10
# 6.3    10
# 5.9    10
# 8.8     9
# 7.6     9
# 5.7     8
# 9.2     8
# 6.9     8
# 7.0     7
# 5.3     7
# 5.6     7
# 5.5     7
# 5.2     5
# 6.0     4
# 9.3     4
# 9.1     3
# 8.9     3
# 5.1     3
# 9.5     2
# 9.0     2
# 5.4     2
# 4.6     1
# 4.2     1
# Name: count, dtype: int64

# %%
resultado = data[data['Title'].str.contains(',')]
resultado
# Out:
#      Num_episode                                              Title  \
# 6              7                                       Run, Kankuro
# 7              8                             Team Kakashi, Deployed
# 86            87     When You Curse Someone, You Dig Your Own Grave
# 118          119  Kakashi Chronicles: A Boy's Life on the Battle...
# 119          120  Kakashi Chronicles: A Boy's Life on the Battle...
# 131          132               In Attendance, the Six Paths of Pain
# 160          161       Surname Is Sarutobi! Given Name, Konohamaru!
# 164          165                              Nine Tails, Captured!
# 169          170  Big Adventure! The Quest for the Fourth Hokage...
# 170          171  Big Adventure! The Quest for the Fourth Hokage...
# 178          179                Kakashi Hatake, the Jonin in Charge
# 185          186                          Ah, the Medicine of Youth
# 218          219                         Kakashi Hatake, The Hokage
# ...

# %%
#data['Title']= data["Title"].str.replace(',', ':')

# %%
resultado['Title'].value_counts()
# Out:
# Title
# Run, Kankuro                                                                                   1
# Shikamaru’s Story, a Cloud Drifting in the Silent Dark, Part 2: Dark Clouds                    1
# Killer Bee Rappuden, Part 2                                                                    1
# To See That Smile, Just One More Time                                                          1
# Sasuke’s Story - Sunrise, Part 1: The Exploding Human                                          1
# Sasuke's Story - Sunrise, Part 2: Coliseum                                                     1
# Sasuke’s Story - Sunrise, Part 3: Fuushin                                                      1
# Sasuke’s Story - Sunrise, Part 4: The Ketsuryugan                                              1
# Sasuke’s Story: Sunrise, Part 5: The Last One                                                  1
# Shikamaru’s Story, A Cloud Drifting in the Silent Dark, Part 1: The State of Affairs           1
# ...

# %%
data.to_csv('naruto_mod.csv',sep=';',index='False')

# %%
#'C:/Program Files/MySQL/MySQL Server 8.0/Uploads/naruto1.csv
